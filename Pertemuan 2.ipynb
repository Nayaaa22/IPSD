# %% [markdown]
# # DS -03-01/Inaya Revalina Putri Mujana - 1206230038

# %%
# Import library yang diperlukan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load data

# %%
# read data csv
sehat = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
sehat
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# melihat bentuk dari data yang akan diolah
sehat.shape
# Out:
# (374, 13)

# %% [markdown]
# # Basic information about the dataset

# %%
sehat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
sehat.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
sehat.head(21)
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0           1    Male   27     Software Engineer             6.1
# 1           2    Male   28                Doctor             6.2
# 2           3    Male   28                Doctor             6.2
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 6           7    Male   29               Teacher             6.3
# 7           8    Male   29                Doctor             7.8
# 8           9    Male   29                Doctor             7.8
# 9          10    Male   29                Doctor             7.8
# 10         11    Male   29                Doctor             6.1
# 11         12    Male   29                Doctor             7.8
# 12         13    Male   29                Doctor             6.1
# ...

# %% [markdown]
# # Cek nilai duplikat, nilai unik

# %%
sehat.duplicated().sum()
# Out:
# 0

# %%
unique_counts = sehat.nunique()
unique_counts
# Out:
# Person ID                  374
# Gender                       2
# Age                         31
# Occupation                  11
# Sleep Duration              27
# Quality of Sleep             6
# Physical Activity Level     16
# Stress Level                 6
# BMI Category                 4
# Blood Pressure              25
# Heart Rate                  19
# Daily Steps                 20
# Sleep Disorder               3
# dtype: int64

# %% [markdown]
# # Visualisasikan jumlah nilai unik

# %%
plt.figure(figsize=(20, 10))
plt.bar(unique_counts.index , unique_counts.values, color='pink')

plt.xlabel('Kolom')
plt.ylabel('Jumlah Nilai Unik')
plt.title('Jumlah Nilai Unik per Kolom dalam Dataset')

# Menambahkan label di atas batang
for i, count in enumerate(unique_counts):
    plt.text(i, count + 0.1, str(count), ha='center')

# Menampilkan diagram
plt.tight_layout()
plt.show()

# %% [markdown]
# # Menemukan null values

# %%
sehat.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %% [markdown]
# # Mengetahui tipe data dari dataset

# %%
print(f'Tipe data setiap kolom:\n{sehat.dtypes}')
# Out:
# Tipe data setiap kolom:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %% [markdown]
# # Filter data (contoh filter berdasarkan kolom tertentu)

# %%
#disini saya mengambil kolom Quality of Sleep sebagai contohnya
filtered_data = sehat[sehat['Quality of Sleep'] > 6] 
filtered_data
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 7            8    Male   29     Doctor             7.8                 7
# 8            9    Male   29     Doctor             7.8                 7
# 9           10    Male   29     Doctor             7.8                 7
# 11          12    Male   29     Doctor             7.8                 7
# 19          20    Male   30     Doctor             7.6                 7
# ..         ...     ...  ...        ...             ...               ...
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %% [markdown]
# # Create a box plot (boxplot untuk semua tipe kolom numerik)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=sehat)
plt.title('Box Plot untuk Dataset')
plt.xticks(rotation=90)
plt.show()

# %%
# boxplot antara quality of sleep dan stress level
plt.figure(figsize=(10, 6))
sns.boxplot(x='Stress Level', y='Quality of Sleep', data=sehat)
plt.title('Boxplot: Quality of Sleep vs Stress Level')
plt.show()

# %% [markdown]
# # Correlation

# %%
sehat_numerik = sehat.select_dtypes(include=['float64', 'int64'])

correlation_matrix = sehat_numerik.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Matriks Korelasi')
plt.show()

# Mengurutkan korelasi dan menampilkan korelasi tertinggi
corr_tertinggi = correlation_matrix.unstack().sort_values(ascending=False)

# Mengabaikan korelasi dengan diri sendiri (nilai 1.0) dan menampilkan korelasi tertinggi
print("Kolom dengan korelasi paling tinggi:\n", corr_tertinggi[corr_tertinggi < 1].head(1))
# Out:
# Kolom dengan korelasi paling tinggi:
#  Age  Person ID    0.990516
# dtype: float64
